# %% [markdown]
# # Import Libraries
# And specify the path to ur folder.

# %%
from bs4 import BeautifulSoup
import requests
import os
import pandas as pd
import re
path = '/Users/apple/Desktop/py/series'
os.chdir(path)

# %% [markdown]
# # Specify the url
# *Beautiful Soup is a library that makes it easy to scrape information from web pages.

# %%
url = 'https://www.imdb.com/search/title/?title_type=tv_series&start=101&ref_=adv_prv'
response = requests.get(url)
soup=BeautifulSoup(response.text, 'lxml')

# %% [markdown]
# # Identify what you want to scrape and navigate to the tag to get the required info, for instance, if we want to get the genre,
# this is how each container looks ---->

# %%
containers = soup.find_all('div', class_ = 'lister-item mode-advanced')
containers[1]
# Out:
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt5071412"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt5071412/"> <img alt="Ozark" class="loadlate" data-tconst="tt5071412" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BODIyNzk5NDg5M15BMl5BanBnXkFtZTgwMTE5NjA5MjI@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB470041630_.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">102.</span>
# <a href="/title/tt5071412/">Ozark</a>
# <span class="lister-item-year text-muted unbold">(2017– )</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">16+</span>
# <span class="ghost">|</span>
# <span class="runtime">60 min</span>
# <span class="ghost">|</span>
# ...

# %% [markdown]
# # get genre for the container -->
# specify the tags after find

# %%
containers[1].p.find('span',class_ = 'genre').text.replace('\n', '')
# Out:
# 'Crime, Drama, Thriller            '

# %% [markdown]
# # store scraped info in lists

# %%
names=[]
years=[]
genre=[]
ratings=[]
votes=[]
links = []
    
    
movie_containers = soup.find_all('div', class_ = 'lister-item mode-advanced')
for i in range(len(movie_containers)):
        
    name = movie_containers[i].h3.a.text
    names.append(name)
        # The year
    year = movie_containers[i].h3.find('span', class_ = 'lister-item-year').text
    years.append(year)
    try:
        l = movie_containers[1].find('h3',class_ ='lister-item-header').a.get('href')
    except AttributeError:

        l = 'NA'
    links.append(l)
        
    try:
        r = movie_containers[i].find('div', class_ = 'inline-block ratings-imdb-rating').strong.text
    except AttributeError:

        r = 'NA'
    ratings.append(r)
    try:
        v = (movie_containers[i].find('p', class_="sort-num_votes-visible").text.replace('\n', '')).split(':')[1]
    except AttributeError:

        v = 'NA'
    votes.append(v)
    try:
        g = movie_containers[i].p.find('span',class_ = 'genre').text.replace('\n', '')
    except AttributeError:

        g = 'NA'
    genre.append(g)

# %% [markdown]
# # Store it all in a dictionary

# %%
df = pd.DataFrame({'movie': names,
        'year': years,
        'rating': ratings,
        'genre': genre,
        'votes': votes,
        'link' : links
         })

# %%
df
# Out:
#                                             movie          year rating  \
# 0                                            Lost   (2004–2010)    8.3
# 1                                           Ozark      (2017– )    8.3
# 2                                    Fuller House      (2016– )    6.8
# 3                                   Downton Abbey   (2010–2015)    8.7
# 4                            Star Trek: Discovery      (2017– )    7.4
# 5                                          Titans  (I) (2018– )    7.9
# 6                                        Seinfeld   (1989–1998)    8.8
# 7                                        Reprisal      (2019– )    7.6
# 8                                Better Call Saul      (2015– )    8.7
# 9               It's Always Sunny in Philadelphia      (2005– )    8.8
# 10                                 The Grand Tour      (2016– )    8.7
# 11                           Parks and Recreation   (2009–2015)    8.6
# ...

# %% [markdown]
# # the links seem incomplete.

# %%
def fun(s):

    p = 'imdb.com' + s
    return p

df['link'] = df['link'].apply(fun)
df
# Out:
#                                             movie          year rating  \
# 0                                            Lost   (2004–2010)    8.3
# 1                                           Ozark      (2017– )    8.3
# 2                                    Fuller House      (2016– )    6.8
# 3                                   Downton Abbey   (2010–2015)    8.7
# 4                            Star Trek: Discovery      (2017– )    7.4
# 5                                          Titans  (I) (2018– )    7.9
# 6                                        Seinfeld   (1989–1998)    8.8
# 7                                        Reprisal      (2019– )    7.6
# 8                                Better Call Saul      (2015– )    8.7
# 9               It's Always Sunny in Philadelphia      (2005– )    8.8
# 10                                 The Grand Tour      (2016– )    8.7
# 11                           Parks and Recreation   (2009–2015)    8.6
# ...
